# %%
import os, glob, re, cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf

import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

from sklearn.model_selection import train_test_split

from tensorflow import keras
from tensorflow.keras import layers, activations, optimizers, losses, metrics, initializers
from tensorflow.keras.preprocessing import image, image_dataset_from_directory
from tensorflow.keras.applications.resnet_v2 import preprocess_input, decode_predictions

import warnings
warnings.filterwarnings('ignore')

# %%
EPOCHS = 60

# %% [markdown]
# **Data Loader**

# %%
# The code is defining a frame object called `frameObjTrain` which has two empty lists, `img` and `mask`, 
# to store image and mask data respectively.
## defining a frame for image and mask storage
framObjTrain = {'img' : [],
           'mask' : []
          }

## defining data Loader function
def LoadData( frameObj = None, imgPath = None, maskPath = None, shape = 256):
    """
     Loads data from images and masks. This function is used to load image and mask data from images and masks.
     
     @param frameObj - Dictionary to store data in. If None is passed a new dictionary will be created
     @param imgPath - Path to the images.
     @param maskPath - Path to the masks. It is assumed that the images are in png format
     @param shape - Shape of the image.
     
     @return Dictionary with loaded data. If None is passed a new dictionary will be created
    """
    imgNames = os.listdir(imgPath)

    names = []
    maskNames = []
    unames = [imgNames[i].split(')')[0] for i in range(len(imgNames))]
    unames = list(set(unames))

    # Add the names and mask names to the names and mask names.
    for uname in unames:
        names.append(f'{uname}).png')
        maskNames.append(f'{uname})_mask.png')

    imgAddr = f'{imgPath}/'
    maskAddr = f'{maskPath}/'

    # Draw all images and masks in the frameObj.
    for i in range (len(names)):
        img = plt.imread(imgAddr + names[i])
        mask = plt.imread(maskAddr + maskNames[i])

        img = cv2.resize(img, (shape, shape)) 
        mask = cv2.resize(mask, (shape, shape))

        frameObj['img'].append(img)
        frameObj['mask'].append(mask)

    return frameObj

# %%
# The code is loading benign and malignant samples of breast ultrasound images and storing them in the 
# `framObjTrain` object. The `LoadData` function is used to load the 
# images and masks from the specified paths (`imgPath` and `maskPath`) and resize them to a shape of 256x256 pixels. 
# The loaded samples are then added to the `framObjTrain` object.

framObjTrain = LoadData( framObjTrain, imgPath = '/kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign'
                        , maskPath = '/kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign'
                        , shape = 256)

# loading malignant samples

framObjTrain = LoadData( framObjTrain, imgPath = '/kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant'
                        , maskPath = '/kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant'
                        , shape = 256)

# %%
## displaying data loaded by our function
plt.figure(figsize = (10, 7))
plt.subplot(1,2,1)
plt.imshow(framObjTrain['img'][1])
plt.title('Ultra Sound Image')
plt.subplot(1,2,2)
plt.imshow(framObjTrain['mask'][1])
plt.title('Mask for Cancer')
plt.show()

# %% [markdown]
# **Model Defination**

# %%
# The `Conv2dBlock` function creates a convolutional block consisting of two convolutional 
# layers with batch normalization and ReLU activation. It takes an input tensor, 
# the number of filters in the convolutional block, the kernel size, and a flag indicating 
# whether to perform batch normalization. It returns the output tensor after passing through the convolutional block.
def Conv2dBlock(inputTensor, numFilters, kernelSize = 3, doBatchNorm = True):
    """
     Creates a conv block. It is assumed that the input tensor has been preprocessed by the block before.
     
     @param inputTensor - The input tensor to the block. Must be preprocessed by the block
     @param numFilters - The number of filters in the convolution block
     @param kernelSize - The
     @param doBatchNorm
    """
    #first Conv
    x = tf.keras.layers.Conv2D(filters = numFilters, kernel_size = (kernelSize, kernelSize),
                              kernel_initializer = 'he_normal', padding = 'same') (inputTensor)
    
    # Batch normalization. If doBatchNorm is true batch normalization is performed.
    if doBatchNorm:
        x = tf.keras.layers.BatchNormalization()(x)
        
    x =tf.keras.layers.Activation('relu')(x)
    
    #Second Conv
    x = tf.keras.layers.Conv2D(filters = numFilters, kernel_size = (kernelSize, kernelSize),
                              kernel_initializer = 'he_normal', padding = 'same') (x)
    # Batch normalization. If doBatchNorm is true batch normalization is performed.
    if doBatchNorm:
        x = tf.keras.layers.BatchNormalization()(x)
        
    x = tf.keras.layers.Activation('relu')(x)
    
    return x


# Now defining Unet 
def GiveMeUnet(inputImage, numFilters = 16, droupouts = 0.1, doBatchNorm = True):
    """
     Give me unet convolutions. It takes a batch of images and groups them into numFilters * 2 convolutions
     
     @param inputImage - The input image to be convoluted
     @param numFilters - The number of filters in the convolutional layers
     @param droupouts - The number of groupouts to be applied
     @param doBatchNorm - Whether to batch - normalize the input
     
     @return A tuple of ( Conv2dBlock Path )
    """
    # defining encoder Path
    c1 = Conv2dBlock(inputImage, numFilters * 1, kernelSize = 3, doBatchNorm = doBatchNorm)
    p1 = tf.keras.layers.MaxPooling2D((2,2))(c1)
    p1 = tf.keras.layers.Dropout(droupouts)(p1)

    c2 = Conv2dBlock(p1, numFilters * 2, kernelSize = 3, doBatchNorm = doBatchNorm)
    p2 = tf.keras.layers.MaxPooling2D((2,2))(c2)
    p2 = tf.keras.layers.Dropout(droupouts)(p2)

    c3 = Conv2dBlock(p2, numFilters * 4, kernelSize = 3, doBatchNorm = doBatchNorm)
    p3 = tf.keras.layers.MaxPooling2D((2,2))(c3)
    p3 = tf.keras.layers.Dropout(droupouts)(p3)

    c4 = Conv2dBlock(p3, numFilters * 8, kernelSize = 3, doBatchNorm = doBatchNorm)
    p4 = tf.keras.layers.MaxPooling2D((2,2))(c4)
    p4 = tf.keras.layers.Dropout(droupouts)(p4)

    c5 = Conv2dBlock(p4, numFilters * 16, kernelSize = 3, doBatchNorm = doBatchNorm)

    # defining decoder path
    u6 = tf.keras.layers.Conv2DTranspose(numFilters*8, (3, 3), strides = (2, 2), padding = 'same')(c5)
    u6 = tf.keras.layers.concatenate([u6, c4])
    u6 = tf.keras.layers.Dropout(droupouts)(u6)
    c6 = Conv2dBlock(u6, numFilters * 8, kernelSize = 3, doBatchNorm = doBatchNorm)

    u7 = tf.keras.layers.Conv2DTranspose(numFilters*4, (3, 3), strides = (2, 2), padding = 'same')(c6)

    u7 = tf.keras.layers.concatenate([u7, c3])
    u7 = tf.keras.layers.Dropout(droupouts)(u7)
    c7 = Conv2dBlock(u7, numFilters * 4, kernelSize = 3, doBatchNorm = doBatchNorm)

    u8 = tf.keras.layers.Conv2DTranspose(numFilters*2, (3, 3), strides = (2, 2), padding = 'same')(c7)
    u8 = tf.keras.layers.concatenate([u8, c2])
    u8 = tf.keras.layers.Dropout(droupouts)(u8)
    c8 = Conv2dBlock(u8, numFilters * 2, kernelSize = 3, doBatchNorm = doBatchNorm)

    u9 = tf.keras.layers.Conv2DTranspose(numFilters*1, (3, 3), strides = (2, 2), padding = 'same')(c8)
    u9 = tf.keras.layers.concatenate([u9, c1])
    u9 = tf.keras.layers.Dropout(droupouts)(u9)
    c9 = Conv2dBlock(u9, numFilters * 1, kernelSize = 3, doBatchNorm = doBatchNorm)

    output = tf.keras.layers.Conv2D(1, (1, 1), activation = 'sigmoid')(c9)
    return tf.keras.Model(inputs = [inputImage], outputs = [output])

# %% [markdown]
# **Model Instantiation**

# %%
## instanctiating model
inputs = tf.keras.layers.Input((256, 256, 3))
myTransformer = GiveMeUnet(inputs, droupouts= 0.07)
myTransformer.compile(optimizer = 'Adam', loss = 'binary_crossentropy', metrics = ['accuracy'] )

# %% [markdown]
# **Training For 60 Epochs**

# %%
# %%time

# The code is fitting a transformer model to an image dataset. 
# It measures the time taken for the fitting process using the `%%time` magic command. 
# The `fit` function is called on the `myTransformer` object, passing in the image data (`framObjTrain['img']`) 
# and the corresponding mask data (`framObjTrain['mask']`). The fitting process is performed for a 
# specified number of epochs (`EPOCHS`) with no verbosity (`verbose = 0`). 
# Additionally, the fitting process is parallelized using 4 workers and multiprocessing is enabled. 
# The return value of the `fit` function is stored in the `retVal` variable.

retVal = myTransformer.fit(np.array(framObjTrain['img']), np.array(framObjTrain['mask']), epochs = EPOCHS, verbose = 0,
                          workers=4,
                          use_multiprocessing=True)
# Out:
# 2025-05-10 12:06:25.402723: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel_2/dropout_9/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# CPU times: user 4min 20s, sys: 12.7 s, total: 4min 32s
# Wall time: 5min 42s

# %%
plt.plot(retVal.history['loss'], label = 'training_loss')
plt.plot(retVal.history['accuracy'], label = 'training_accuracy')
plt.legend()
plt.grid(True)

# %% [markdown]
# **Testing**

# %%
def predict16(valMap, model, shape = 256):
    ## getting and proccessing val data
    img = valMap['img'][:16]
    mask = valMap['mask'][:16]

    imgProc = img[:16]
    imgProc = np.array(img)

    predictions = model.predict(imgProc)


    return predictions, imgProc, mask


def Plotter(img, predMask, groundTruth):
    plt.figure(figsize=(9,9))

    _extracted_from_Plotter_4(1, img, ' image')
    _extracted_from_Plotter_4(2, predMask, 'Predicted mask')
    _extracted_from_Plotter_4(3, groundTruth, 'Actual mask')


# TODO Rename this here and in `Plotter`
def _extracted_from_Plotter_4(arg0, arg1, arg2):
    plt.subplot(1, 3, arg0)
    plt.imshow(arg1)
    plt.title(arg2)

# %%
sixteenPrediction, actuals, masks = predict16(framObjTrain, myTransformer)
Plotter(actuals[1], sixteenPrediction[1][:,:,0], masks[1])
# Out:
# 1/1 [==============================] - 0s 362ms/step

# %%
Plotter(actuals[2], sixteenPrediction[2][:,:,0], masks[2])

# %%
Plotter(actuals[3], sixteenPrediction[3][:,:,0], masks[3])

# %%
Plotter(actuals[5], sixteenPrediction[5][:,:,0], masks[5])

# %%
Plotter(actuals[7], sixteenPrediction[7][:,:,0], masks[7])

# %%
Plotter(actuals[8], sixteenPrediction[8][:,:,0], masks[8])

# %%
Plotter(actuals[9], sixteenPrediction[9][:,:,0], masks[9])

# %%
Plotter(actuals[10], sixteenPrediction[10][:,:,0], masks[10])

# %% [markdown]
# **Saving Model**

# %%
myTransformer.save('BreastCancerSegmentor.h5')

# %%
dir_path = '/kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/'
IMAGE_SHAPE = (224, 224)

# %% [markdown]
# **Build Functions**

# %%
# create prepare_image method
# used to preprocess the image for efficientNet model
def prepare_image(file):
    img = image.load_img(file, target_size=IMAGE_SHAPE)
    img_array = image.img_to_array(img)
    return tf.keras.applications.efficientnet.preprocess_input (img_array)

# %%
directories = os.listdir(dir_path) # read the folders

files = [] # save all images for each folder
labels = [] # set for each image the name of it

# read files for each directory
for folder in directories:
    
    fileList = glob.glob(f'{dir_path}/{folder}/*')
    labels.extend([folder for _ in fileList])
    files.extend(fileList)

len(files), len(labels)
# Out:
# (1578, 1578)

# %% [markdown]
# **Remove any mask image from files**

# %%
# create two lists to hold only non-mask images and label for each one
selected_files = []
selected_labels = []

for file, label in zip(files, labels):
    if 'mask' not in file:
        selected_files.append(file)
        selected_labels.append(label)

    
len(selected_files), len(selected_labels)
# Out:
# (780, 780)

# %%
# the dictionary holds list of images and for each one has its target/label
images = {
    'image': [], 
    'target': []
}

print('Preparing the image...')

for file, label in zip(selected_files, selected_labels):
    images['image'].append(prepare_image(file))
    images['target'].append(label)

print('Finished.')
# Out:
# Preparing the image...
# Finished.

# %% [markdown]
# **Prepare the target for splitting**

# %%
# convert lists to arrays 
images['image'] = np.array(images['image'])
images['target'] = np.array(images['target'])

# encode the target
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

images['target'] = le.fit_transform(images['target'])

classes = le.classes_ # get the classes for each target
print(f'the target classes are: {classes}')
# Out:
# the target classes are: ['benign' 'malignant' 'normal']

# %% [markdown]
# **Split the data to train and test**

# %%
x_train, x_test, y_train, y_test = train_test_split(images['image'], images['target'], test_size=.10)

x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((702, 224, 224, 3), (78, 224, 224, 3), (702,), (78,))

# %% [markdown]
# **Build the Model**
#
# * create ResNet152V2 Model
# * don't include_top layers to take only the features of the model
# * freeze all layer weights of the model
# * append my own layers for Transfer Learning
# * compile my own model after Transfer Learning

# %%
# The code is creating a ResNet152V2 model with pre-trained weights from the ImageNet dataset. 
# The base model is frozen, meaning its weights will not be updated during training. 
# The code then appends additional layers on top of the base model for transfer learning.

from tensorflow.keras.applications import resnet_v2
base_model = resnet_v2.ResNet152V2(
    include_top=False,
    weights='imagenet',
    input_shape=(*IMAGE_SHAPE, 3),
    classes=3)

# Freeze the base_model
base_model.trainable = False

# append my own layers on the top of the model for Transfer Learning
x = base_model.output

# 1st conv block
x = layers.Conv2D(256, 3, padding='same')(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)
x = layers.GlobalAveragePooling2D(keepdims = True)(x)

# 2nd conv block
x = layers.Conv2D(128, 3, padding='same')(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)
x = layers.GlobalAveragePooling2D(keepdims = True)(x)

# 1st FC layer
x = layers.Flatten()(x) 
x = layers.Dense(64)(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)

# 2nd FC layer
x = layers.Dense(32, activation = 'relu')(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)
x = layers.Dropout(.2)(x)

x = layers.Dense(3, 'softmax')(x)

incept_model = keras.models.Model(inputs = base_model.input, outputs = x)

# compile the model
incept_model.compile(optimizer=optimizers.RMSprop(.001), loss = losses.sparse_categorical_crossentropy, metrics= [metrics.SparseCategoricalAccuracy()])

# incept_model.summary()

# %% [markdown]
# **Train the mode**

# %%
# %%time

# Trains and returns incept_model. fit ( x_train y_train )
earlyStop = keras.callbacks.EarlyStopping(patience=60) 
best_model = keras.callbacks.ModelCheckpoint(filepath='best_model.h5', save_best_only=True) 

with tf.device('/gpu:0'):
    history = incept_model.fit(x_train, y_train, batch_size=32, epochs=EPOCHS, validation_data=(x_test, y_test), callbacks=[earlyStop, best_model])
# Out:
# Epoch 1/60
# 22/22 [==============================] - 17s 326ms/step - loss: 1.1308 - sparse_categorical_accuracy: 0.4701 - val_loss: 1.6666 - val_sparse_categorical_accuracy: 0.5897
# Epoch 2/60
# 22/22 [==============================] - 5s 212ms/step - loss: 1.0514 - sparse_categorical_accuracy: 0.5242 - val_loss: 1.1654 - val_sparse_categorical_accuracy: 0.6154
# Epoch 3/60
# 22/22 [==============================] - 5s 212ms/step - loss: 0.9691 - sparse_categorical_accuracy: 0.5912 - val_loss: 1.0511 - val_sparse_categorical_accuracy: 0.5897
# Epoch 4/60
# 22/22 [==============================] - 3s 149ms/step - loss: 0.9919 - sparse_categorical_accuracy: 0.5470 - val_loss: 1.0642 - val_sparse_categorical_accuracy: 0.4359
# Epoch 5/60
# 22/22 [==============================] - 5s 210ms/step - loss: 0.9071 - sparse_categorical_accuracy: 0.5869 - val_loss: 1.0454 - val_sparse_categorical_accuracy: 0.5897
# Epoch 6/60
# 22/22 [==============================] - 3s 149ms/step - loss: 0.9174 - sparse_categorical_accuracy: 0.5954 - val_loss: 1.3885 - val_sparse_categorical_accuracy: 0.6154
# Epoch 7/60
# 22/22 [==============================] - 3s 149ms/step - loss: 0.8480 - sparse_categorical_accuracy: 0.6325 - val_loss: 1.0584 - val_sparse_categorical_accuracy: 0.6026
# Epoch 8/60
# 22/22 [==============================] - 3s 151ms/step - loss: 0.8262 - sparse_categorical_accuracy: 0.6325 - val_loss: 1.0527 - val_sparse_categorical_accuracy: 0.5128
# Epoch 9/60
# 22/22 [==============================] - 5s 211ms/step - loss: 0.7862 - sparse_categorical_accuracy: 0.6624 - val_loss: 0.9917 - val_sparse_categorical_accuracy: 0.6410
# Epoch 10/60
# 22/22 [==============================] - 3s 149ms/step - loss: 0.7749 - sparse_categorical_accuracy: 0.6567 - val_loss: 1.4113 - val_sparse_categorical_accuracy: 0.6154
# Epoch 11/60
# 22/22 [==============================] - 3s 149ms/step - loss: 0.7391 - sparse_categorical_accuracy: 0.6681 - val_loss: 1.0059 - val_sparse_categorical_accuracy: 0.5513
# Epoch 12/60
# 22/22 [==============================] - 5s 212ms/step - loss: 0.6991 - sparse_categorical_accuracy: 0.6937 - val_loss: 0.8806 - val_sparse_categorical_accuracy: 0.7179
# Epoch 13/60
# 22/22 [==============================] - 3s 149ms/step - loss: 0.7130 - sparse_categorical_accuracy: 0.6980 - val_loss: 0.9563 - val_sparse_categorical_accuracy: 0.6026
# Epoch 14/60
# 22/22 [==============================] - 3s 150ms/step - loss: 0.6624 - sparse_categorical_accuracy: 0.7108 - val_loss: 2.5852 - val_sparse_categorical_accuracy: 0.6026
# Epoch 15/60
# 22/22 [==============================] - 3s 149ms/step - loss: 0.6699 - sparse_categorical_accuracy: 0.7179 - val_loss: 0.9989 - val_sparse_categorical_accuracy: 0.5769
# Epoch 16/60
# 22/22 [==============================] - 3s 149ms/step - loss: 0.6669 - sparse_categorical_accuracy: 0.7208 - val_loss: 1.5493 - val_sparse_categorical_accuracy: 0.6282
# Epoch 17/60
# 22/22 [==============================] - 3s 149ms/step - loss: 0.6227 - sparse_categorical_accuracy: 0.7393 - val_loss: 1.3345 - val_sparse_categorical_accuracy: 0.3718
# Epoch 18/60
# 22/22 [==============================] - 3s 148ms/step - loss: 0.6305 - sparse_categorical_accuracy: 0.7279 - val_loss: 3.4675 - val_sparse_categorical_accuracy: 0.2692
# Epoch 19/60
# 22/22 [==============================] - 3s 149ms/step - loss: 0.5736 - sparse_categorical_accuracy: 0.7550 - val_loss: 1.0951 - val_sparse_categorical_accuracy: 0.4744
# Epoch 20/60
# 22/22 [==============================] - 3s 149ms/step - loss: 0.5882 - sparse_categorical_accuracy: 0.7536 - val_loss: 2.5081 - val_sparse_categorical_accuracy: 0.5897
# Epoch 21/60
# 22/22 [==============================] - 3s 149ms/step - loss: 0.5951 - sparse_categorical_accuracy: 0.7578 - val_loss: 1.5574 - val_sparse_categorical_accuracy: 0.5769
# Epoch 22/60
# 22/22 [==============================] - 3s 149ms/step - loss: 0.5449 - sparse_categorical_accuracy: 0.7707 - val_loss: 1.2510 - val_sparse_categorical_accuracy: 0.5385
# Epoch 23/60
# 22/22 [==============================] - 3s 148ms/step - loss: 0.5616 - sparse_categorical_accuracy: 0.7507 - val_loss: 1.9971 - val_sparse_categorical_accuracy: 0.6923
# Epoch 24/60
# 22/22 [==============================] - 3s 149ms/step - loss: 0.5451 - sparse_categorical_accuracy: 0.7707 - val_loss: 1.6591 - val_sparse_categorical_accuracy: 0.6410
# Epoch 25/60
# 22/22 [==============================] - 3s 149ms/step - loss: 0.5436 - sparse_categorical_accuracy: 0.7650 - val_loss: 3.3892 - val_sparse_categorical_accuracy: 0.3205
# Epoch 26/60
# 22/22 [==============================] - 3s 149ms/step - loss: 0.5128 - sparse_categorical_accuracy: 0.7821 - val_loss: 1.3521 - val_sparse_categorical_accuracy: 0.3333
# Epoch 27/60
# 22/22 [==============================] - 3s 150ms/step - loss: 0.5563 - sparse_categorical_accuracy: 0.7621 - val_loss: 3.3014 - val_sparse_categorical_accuracy: 0.2949
# Epoch 28/60
# 22/22 [==============================] - 3s 150ms/step - loss: 0.5136 - sparse_categorical_accuracy: 0.7806 - val_loss: 1.2299 - val_sparse_categorical_accuracy: 0.6410
# Epoch 29/60
# 22/22 [==============================] - 3s 149ms/step - loss: 0.5429 - sparse_categorical_accuracy: 0.7735 - val_loss: 1.0962 - val_sparse_categorical_accuracy: 0.5128
# Epoch 30/60
# 22/22 [==============================] - 3s 149ms/step - loss: 0.5120 - sparse_categorical_accuracy: 0.7806 - val_loss: 1.3492 - val_sparse_categorical_accuracy: 0.5897
# Epoch 31/60
# 22/22 [==============================] - 3s 149ms/step - loss: 0.5126 - sparse_categorical_accuracy: 0.8006 - val_loss: 2.6693 - val_sparse_categorical_accuracy: 0.6410
# Epoch 32/60
# 22/22 [==============================] - 3s 150ms/step - loss: 0.4849 - sparse_categorical_accuracy: 0.7963 - val_loss: 1.2534 - val_sparse_categorical_accuracy: 0.6923
# Epoch 33/60
# 22/22 [==============================] - 3s 149ms/step - loss: 0.4713 - sparse_categorical_accuracy: 0.8120 - val_loss: 4.1342 - val_sparse_categorical_accuracy: 0.6282
# Epoch 34/60
# 22/22 [==============================] - 3s 149ms/step - loss: 0.4242 - sparse_categorical_accuracy: 0.8276 - val_loss: 3.1978 - val_sparse_categorical_accuracy: 0.6154
# Epoch 35/60
# 22/22 [==============================] - 3s 150ms/step - loss: 0.4601 - sparse_categorical_accuracy: 0.8063 - val_loss: 2.7618 - val_sparse_categorical_accuracy: 0.2436
# Epoch 36/60
# 22/22 [==============================] - 3s 151ms/step - loss: 0.4503 - sparse_categorical_accuracy: 0.8262 - val_loss: 2.2077 - val_sparse_categorical_accuracy: 0.4103
# Epoch 37/60
# 22/22 [==============================] - 3s 150ms/step - loss: 0.4553 - sparse_categorical_accuracy: 0.8191 - val_loss: 4.3561 - val_sparse_categorical_accuracy: 0.5897
# Epoch 38/60
# 22/22 [==============================] - 3s 150ms/step - loss: 0.4296 - sparse_categorical_accuracy: 0.8234 - val_loss: 3.1505 - val_sparse_categorical_accuracy: 0.6026
# Epoch 39/60
# 22/22 [==============================] - 3s 150ms/step - loss: 0.3884 - sparse_categorical_accuracy: 0.8333 - val_loss: 3.0087 - val_sparse_categorical_accuracy: 0.2821
# Epoch 40/60
# 22/22 [==============================] - 3s 150ms/step - loss: 0.4156 - sparse_categorical_accuracy: 0.8305 - val_loss: 1.8378 - val_sparse_categorical_accuracy: 0.6538
# Epoch 41/60
# 22/22 [==============================] - 3s 150ms/step - loss: 0.3720 - sparse_categorical_accuracy: 0.8547 - val_loss: 0.9717 - val_sparse_categorical_accuracy: 0.5000
# Epoch 42/60
# 22/22 [==============================] - 3s 149ms/step - loss: 0.3850 - sparse_categorical_accuracy: 0.8490 - val_loss: 1.8927 - val_sparse_categorical_accuracy: 0.5769
# Epoch 43/60
# 22/22 [==============================] - 3s 149ms/step - loss: 0.3751 - sparse_categorical_accuracy: 0.8575 - val_loss: 1.7314 - val_sparse_categorical_accuracy: 0.4872
# Epoch 44/60
# 22/22 [==============================] - 3s 150ms/step - loss: 0.4031 - sparse_categorical_accuracy: 0.8419 - val_loss: 1.1544 - val_sparse_categorical_accuracy: 0.5385
# Epoch 45/60
# 22/22 [==============================] - 3s 149ms/step - loss: 0.3847 - sparse_categorical_accuracy: 0.8575 - val_loss: 1.1694 - val_sparse_categorical_accuracy: 0.7179
# Epoch 46/60
# 22/22 [==============================] - 3s 149ms/step - loss: 0.3634 - sparse_categorical_accuracy: 0.8447 - val_loss: 3.2354 - val_sparse_categorical_accuracy: 0.6026
# Epoch 47/60
# 22/22 [==============================] - 3s 149ms/step - loss: 0.3452 - sparse_categorical_accuracy: 0.8561 - val_loss: 3.0566 - val_sparse_categorical_accuracy: 0.3205
# Epoch 48/60
# 22/22 [==============================] - 3s 148ms/step - loss: 0.3380 - sparse_categorical_accuracy: 0.8732 - val_loss: 1.0775 - val_sparse_categorical_accuracy: 0.6538
# Epoch 49/60
# 22/22 [==============================] - 3s 149ms/step - loss: 0.3655 - sparse_categorical_accuracy: 0.8504 - val_loss: 1.8485 - val_sparse_categorical_accuracy: 0.6154
# Epoch 50/60
# 22/22 [==============================] - 3s 149ms/step - loss: 0.3506 - sparse_categorical_accuracy: 0.8618 - val_loss: 2.7722 - val_sparse_categorical_accuracy: 0.6538
# Epoch 51/60
# 22/22 [==============================] - 3s 149ms/step - loss: 0.3500 - sparse_categorical_accuracy: 0.8675 - val_loss: 2.1745 - val_sparse_categorical_accuracy: 0.6667
# Epoch 52/60
# 22/22 [==============================] - 3s 148ms/step - loss: 0.3254 - sparse_categorical_accuracy: 0.8718 - val_loss: 1.3553 - val_sparse_categorical_accuracy: 0.4615
# Epoch 53/60
# 22/22 [==============================] - 3s 148ms/step - loss: 0.3677 - sparse_categorical_accuracy: 0.8575 - val_loss: 1.1270 - val_sparse_categorical_accuracy: 0.6795
# Epoch 54/60
# 22/22 [==============================] - 3s 149ms/step - loss: 0.3086 - sparse_categorical_accuracy: 0.8818 - val_loss: 6.9910 - val_sparse_categorical_accuracy: 0.5897
# Epoch 55/60
# 22/22 [==============================] - 3s 149ms/step - loss: 0.3651 - sparse_categorical_accuracy: 0.8519 - val_loss: 4.7300 - val_sparse_categorical_accuracy: 0.5897
# Epoch 56/60
# 22/22 [==============================] - 3s 150ms/step - loss: 0.2996 - sparse_categorical_accuracy: 0.8818 - val_loss: 1.8205 - val_sparse_categorical_accuracy: 0.6282
# Epoch 57/60
# 22/22 [==============================] - 3s 148ms/step - loss: 0.3009 - sparse_categorical_accuracy: 0.8675 - val_loss: 2.8679 - val_sparse_categorical_accuracy: 0.3590
# Epoch 58/60
# 22/22 [==============================] - 3s 149ms/step - loss: 0.3113 - sparse_categorical_accuracy: 0.8803 - val_loss: 1.6160 - val_sparse_categorical_accuracy: 0.5000
# Epoch 59/60
# 22/22 [==============================] - 3s 150ms/step - loss: 0.2626 - sparse_categorical_accuracy: 0.8932 - val_loss: 3.9272 - val_sparse_categorical_accuracy: 0.6026
# Epoch 60/60
# 22/22 [==============================] - 3s 149ms/step - loss: 0.2786 - sparse_categorical_accuracy: 0.8875 - val_loss: 1.2205 - val_sparse_categorical_accuracy: 0.5513
# CPU times: user 1min 25s, sys: 9.99 s, total: 1min 35s
# Wall time: 3min 37s

# %%
hist = history.history

plt.plot(hist['loss'], label=  'loss')
plt.plot(hist['val_loss'], label = 'val_loss')
plt.plot(hist['sparse_categorical_accuracy'], label='accuracy')
plt.plot(hist['val_sparse_categorical_accuracy'], label='val_accuracy')
plt.legend()

# %% [markdown]
# **Evaluate the model**

# %%
incept_model.evaluate(x=x_test, y = y_test, batch_size=32, verbose=1)
# Out:
# 3/3 [==============================] - 0s 100ms/step - loss: 1.2205 - sparse_categorical_accuracy: 0.5513
# [1.2205238342285156, 0.5512820482254028]

# %% [markdown]
# **Make the last 100 layers as trainable**

# %%
# open train the last 100 layers
for layer in incept_model.layers[720:]:
    layer.trainable = True
    
# compile the model with new optimizer and lr=.0001
incept_model.compile(optimizer=optimizers.RMSprop(.0001), loss = losses.sparse_categorical_crossentropy, metrics=[metrics.SparseCategoricalAccuracy()])

# incept_model.summary()

# %% [markdown]
# **Train the model again**

# %%
earlyStop = keras.callbacks.EarlyStopping(patience=60) 
best_model = keras.callbacks.ModelCheckpoint(filepath='best_model_2.h5', save_best_only=True) 

# load the best weights
# incept_model.set_weights(best_weights)

with tf.device('/gpu:0'):
    history = incept_model.fit(x_train, y_train, batch_size=32, epochs=EPOCHS, validation_data=(x_test, y_test), callbacks=[earlyStop, best_model])
# Out:
# Epoch 1/60
# 22/22 [==============================] - 16s 332ms/step - loss: 0.2202 - sparse_categorical_accuracy: 0.9131 - val_loss: 0.9205 - val_sparse_categorical_accuracy: 0.6923
# Epoch 2/60
# 22/22 [==============================] - 6s 266ms/step - loss: 0.1803 - sparse_categorical_accuracy: 0.9345 - val_loss: 0.9062 - val_sparse_categorical_accuracy: 0.6667
# Epoch 3/60
# 22/22 [==============================] - 3s 150ms/step - loss: 0.1817 - sparse_categorical_accuracy: 0.9402 - val_loss: 0.9170 - val_sparse_categorical_accuracy: 0.7051
# Epoch 4/60
# 22/22 [==============================] - 3s 150ms/step - loss: 0.1630 - sparse_categorical_accuracy: 0.9544 - val_loss: 0.9318 - val_sparse_categorical_accuracy: 0.6923
# Epoch 5/60
# 22/22 [==============================] - 5s 216ms/step - loss: 0.1625 - sparse_categorical_accuracy: 0.9530 - val_loss: 0.8248 - val_sparse_categorical_accuracy: 0.7308
# Epoch 6/60
# 22/22 [==============================] - 3s 149ms/step - loss: 0.1709 - sparse_categorical_accuracy: 0.9373 - val_loss: 0.8750 - val_sparse_categorical_accuracy: 0.6667
# Epoch 7/60
# 22/22 [==============================] - 5s 213ms/step - loss: 0.1563 - sparse_categorical_accuracy: 0.9501 - val_loss: 0.7954 - val_sparse_categorical_accuracy: 0.7179
# Epoch 8/60
# 22/22 [==============================] - 3s 150ms/step - loss: 0.1419 - sparse_categorical_accuracy: 0.9558 - val_loss: 1.1699 - val_sparse_categorical_accuracy: 0.6923
# Epoch 9/60
# 22/22 [==============================] - 3s 151ms/step - loss: 0.1564 - sparse_categorical_accuracy: 0.9473 - val_loss: 1.0260 - val_sparse_categorical_accuracy: 0.6538
# Epoch 10/60
# 22/22 [==============================] - 3s 150ms/step - loss: 0.1532 - sparse_categorical_accuracy: 0.9501 - val_loss: 0.9652 - val_sparse_categorical_accuracy: 0.7179
# Epoch 11/60
# 22/22 [==============================] - 3s 150ms/step - loss: 0.1458 - sparse_categorical_accuracy: 0.9430 - val_loss: 1.1227 - val_sparse_categorical_accuracy: 0.6923
# Epoch 12/60
# 22/22 [==============================] - 3s 150ms/step - loss: 0.1342 - sparse_categorical_accuracy: 0.9544 - val_loss: 0.9848 - val_sparse_categorical_accuracy: 0.6795
# Epoch 13/60
# 22/22 [==============================] - 3s 148ms/step - loss: 0.1325 - sparse_categorical_accuracy: 0.9558 - val_loss: 0.9002 - val_sparse_categorical_accuracy: 0.7308
# Epoch 14/60
# 22/22 [==============================] - 3s 150ms/step - loss: 0.1601 - sparse_categorical_accuracy: 0.9473 - val_loss: 0.8927 - val_sparse_categorical_accuracy: 0.7564
# Epoch 15/60
# 22/22 [==============================] - 3s 150ms/step - loss: 0.1563 - sparse_categorical_accuracy: 0.9487 - val_loss: 0.8509 - val_sparse_categorical_accuracy: 0.7308
# Epoch 16/60
# 22/22 [==============================] - 3s 149ms/step - loss: 0.1484 - sparse_categorical_accuracy: 0.9558 - val_loss: 1.0332 - val_sparse_categorical_accuracy: 0.7051
# Epoch 17/60
# 22/22 [==============================] - 3s 150ms/step - loss: 0.1426 - sparse_categorical_accuracy: 0.9516 - val_loss: 1.4681 - val_sparse_categorical_accuracy: 0.7436
# Epoch 18/60
# 22/22 [==============================] - 3s 150ms/step - loss: 0.1353 - sparse_categorical_accuracy: 0.9544 - val_loss: 1.2090 - val_sparse_categorical_accuracy: 0.7308
# Epoch 19/60
# 22/22 [==============================] - 3s 150ms/step - loss: 0.1484 - sparse_categorical_accuracy: 0.9487 - val_loss: 1.0731 - val_sparse_categorical_accuracy: 0.7051
# Epoch 20/60
# 22/22 [==============================] - 3s 150ms/step - loss: 0.1303 - sparse_categorical_accuracy: 0.9558 - val_loss: 1.1273 - val_sparse_categorical_accuracy: 0.6923
# Epoch 21/60
# 22/22 [==============================] - 3s 150ms/step - loss: 0.1525 - sparse_categorical_accuracy: 0.9402 - val_loss: 1.0274 - val_sparse_categorical_accuracy: 0.6923
# Epoch 22/60
# 22/22 [==============================] - 3s 151ms/step - loss: 0.1424 - sparse_categorical_accuracy: 0.9416 - val_loss: 1.1567 - val_sparse_categorical_accuracy: 0.6923
# Epoch 23/60
# 22/22 [==============================] - 3s 150ms/step - loss: 0.1084 - sparse_categorical_accuracy: 0.9630 - val_loss: 1.3767 - val_sparse_categorical_accuracy: 0.7821
# Epoch 24/60
# 22/22 [==============================] - 3s 151ms/step - loss: 0.1345 - sparse_categorical_accuracy: 0.9558 - val_loss: 1.3110 - val_sparse_categorical_accuracy: 0.6026
# Epoch 25/60
# 22/22 [==============================] - 3s 149ms/step - loss: 0.1261 - sparse_categorical_accuracy: 0.9587 - val_loss: 1.0605 - val_sparse_categorical_accuracy: 0.7564
# Epoch 26/60
# 22/22 [==============================] - 3s 149ms/step - loss: 0.1261 - sparse_categorical_accuracy: 0.9658 - val_loss: 0.9110 - val_sparse_categorical_accuracy: 0.7179
# Epoch 27/60
# 22/22 [==============================] - 3s 150ms/step - loss: 0.1261 - sparse_categorical_accuracy: 0.9644 - val_loss: 0.8760 - val_sparse_categorical_accuracy: 0.7821
# Epoch 28/60
# 22/22 [==============================] - 3s 152ms/step - loss: 0.1175 - sparse_categorical_accuracy: 0.9615 - val_loss: 0.9439 - val_sparse_categorical_accuracy: 0.7179
# Epoch 29/60
# 22/22 [==============================] - 3s 150ms/step - loss: 0.1308 - sparse_categorical_accuracy: 0.9587 - val_loss: 1.2420 - val_sparse_categorical_accuracy: 0.6923
# Epoch 30/60
# 22/22 [==============================] - 3s 149ms/step - loss: 0.1132 - sparse_categorical_accuracy: 0.9630 - val_loss: 1.1405 - val_sparse_categorical_accuracy: 0.6795
# Epoch 31/60
# 22/22 [==============================] - 3s 148ms/step - loss: 0.1173 - sparse_categorical_accuracy: 0.9658 - val_loss: 1.5933 - val_sparse_categorical_accuracy: 0.7436
# Epoch 32/60
# 22/22 [==============================] - 3s 150ms/step - loss: 0.1123 - sparse_categorical_accuracy: 0.9601 - val_loss: 0.9941 - val_sparse_categorical_accuracy: 0.6923
# Epoch 33/60
# 22/22 [==============================] - 3s 150ms/step - loss: 0.0988 - sparse_categorical_accuracy: 0.9701 - val_loss: 1.1031 - val_sparse_categorical_accuracy: 0.6667
# Epoch 34/60
# 22/22 [==============================] - 3s 150ms/step - loss: 0.1039 - sparse_categorical_accuracy: 0.9715 - val_loss: 1.0470 - val_sparse_categorical_accuracy: 0.6923
# Epoch 35/60
# 22/22 [==============================] - 3s 150ms/step - loss: 0.1274 - sparse_categorical_accuracy: 0.9544 - val_loss: 1.3076 - val_sparse_categorical_accuracy: 0.7436
# Epoch 36/60
# 22/22 [==============================] - 3s 149ms/step - loss: 0.1023 - sparse_categorical_accuracy: 0.9615 - val_loss: 1.2098 - val_sparse_categorical_accuracy: 0.6538
# Epoch 37/60
# 22/22 [==============================] - 3s 150ms/step - loss: 0.0960 - sparse_categorical_accuracy: 0.9715 - val_loss: 1.1634 - val_sparse_categorical_accuracy: 0.6923
# Epoch 38/60
# 22/22 [==============================] - 3s 150ms/step - loss: 0.1089 - sparse_categorical_accuracy: 0.9715 - val_loss: 1.4648 - val_sparse_categorical_accuracy: 0.7436
# Epoch 39/60
# 22/22 [==============================] - 3s 150ms/step - loss: 0.1233 - sparse_categorical_accuracy: 0.9587 - val_loss: 1.2969 - val_sparse_categorical_accuracy: 0.7436
# Epoch 40/60
# 22/22 [==============================] - 3s 150ms/step - loss: 0.0953 - sparse_categorical_accuracy: 0.9672 - val_loss: 1.1285 - val_sparse_categorical_accuracy: 0.7179
# Epoch 41/60
# 22/22 [==============================] - 3s 149ms/step - loss: 0.1097 - sparse_categorical_accuracy: 0.9658 - val_loss: 1.0968 - val_sparse_categorical_accuracy: 0.7308
# Epoch 42/60
# 22/22 [==============================] - 3s 149ms/step - loss: 0.0914 - sparse_categorical_accuracy: 0.9672 - val_loss: 1.2725 - val_sparse_categorical_accuracy: 0.7308
# Epoch 43/60
# 22/22 [==============================] - 3s 149ms/step - loss: 0.0868 - sparse_categorical_accuracy: 0.9729 - val_loss: 1.2771 - val_sparse_categorical_accuracy: 0.6026
# Epoch 44/60
# 22/22 [==============================] - 3s 150ms/step - loss: 0.0939 - sparse_categorical_accuracy: 0.9715 - val_loss: 1.6040 - val_sparse_categorical_accuracy: 0.5641
# Epoch 45/60
# 22/22 [==============================] - 3s 150ms/step - loss: 0.0989 - sparse_categorical_accuracy: 0.9630 - val_loss: 1.2833 - val_sparse_categorical_accuracy: 0.6923
# Epoch 46/60
# 22/22 [==============================] - 3s 150ms/step - loss: 0.1141 - sparse_categorical_accuracy: 0.9615 - val_loss: 1.1399 - val_sparse_categorical_accuracy: 0.7179
# Epoch 47/60
# 22/22 [==============================] - 3s 150ms/step - loss: 0.1011 - sparse_categorical_accuracy: 0.9687 - val_loss: 1.0984 - val_sparse_categorical_accuracy: 0.7179
# Epoch 48/60
# 22/22 [==============================] - 3s 150ms/step - loss: 0.0911 - sparse_categorical_accuracy: 0.9715 - val_loss: 1.2102 - val_sparse_categorical_accuracy: 0.7179
# Epoch 49/60
# 22/22 [==============================] - 3s 149ms/step - loss: 0.1076 - sparse_categorical_accuracy: 0.9615 - val_loss: 1.3093 - val_sparse_categorical_accuracy: 0.7308
# Epoch 50/60
# 22/22 [==============================] - 3s 150ms/step - loss: 0.1105 - sparse_categorical_accuracy: 0.9601 - val_loss: 1.1778 - val_sparse_categorical_accuracy: 0.7051
# Epoch 51/60
# 22/22 [==============================] - 3s 150ms/step - loss: 0.0918 - sparse_categorical_accuracy: 0.9701 - val_loss: 1.0966 - val_sparse_categorical_accuracy: 0.7179
# Epoch 52/60
# 22/22 [==============================] - 3s 149ms/step - loss: 0.1035 - sparse_categorical_accuracy: 0.9530 - val_loss: 1.5462 - val_sparse_categorical_accuracy: 0.6154
# Epoch 53/60
# 22/22 [==============================] - 3s 150ms/step - loss: 0.0932 - sparse_categorical_accuracy: 0.9758 - val_loss: 1.2260 - val_sparse_categorical_accuracy: 0.6923
# Epoch 54/60
# 22/22 [==============================] - 3s 150ms/step - loss: 0.0936 - sparse_categorical_accuracy: 0.9630 - val_loss: 1.3419 - val_sparse_categorical_accuracy: 0.7051
# Epoch 55/60
# 22/22 [==============================] - 3s 151ms/step - loss: 0.0911 - sparse_categorical_accuracy: 0.9729 - val_loss: 1.3255 - val_sparse_categorical_accuracy: 0.7308
# Epoch 56/60
# 22/22 [==============================] - 3s 150ms/step - loss: 0.0831 - sparse_categorical_accuracy: 0.9715 - val_loss: 1.0492 - val_sparse_categorical_accuracy: 0.7308
# Epoch 57/60
# 22/22 [==============================] - 3s 151ms/step - loss: 0.0847 - sparse_categorical_accuracy: 0.9772 - val_loss: 1.2121 - val_sparse_categorical_accuracy: 0.6923
# Epoch 58/60
# 22/22 [==============================] - 3s 150ms/step - loss: 0.0863 - sparse_categorical_accuracy: 0.9658 - val_loss: 1.3661 - val_sparse_categorical_accuracy: 0.6923
# Epoch 59/60
# 22/22 [==============================] - 3s 150ms/step - loss: 0.1066 - sparse_categorical_accuracy: 0.9630 - val_loss: 1.4375 - val_sparse_categorical_accuracy: 0.6026
# Epoch 60/60
# 22/22 [==============================] - 3s 150ms/step - loss: 0.0844 - sparse_categorical_accuracy: 0.9715 - val_loss: 1.2286 - val_sparse_categorical_accuracy: 0.6795

# %% [markdown]
# **Evaluate the model**

# %%
incept_model.evaluate(x=x_test, y = y_test, batch_size=32, verbose=1)
# Out:
# 3/3 [==============================] - 0s 105ms/step - loss: 1.2286 - sparse_categorical_accuracy: 0.6795
# [1.2286336421966553, 0.6794871687889099]

# %% [markdown]
# **Predict the model**

# %%
# used to predict the model and visualize the orignal image with title of true and pred values
def predict_image(img_path, label):
    img1 = prepare_image(img_path) # preprocess the image
    res = incept_model.predict(np.expand_dims(img1, axis = 0)) # predict the image
    pred = classes[np.argmax(res)]

    # Visualize the image
    img = image.load_img(img_path)
    plt.imshow(np.array(img))
    plt.title(f'True: {label}\nPredicted: {pred}')

# %%
predict_image(f'{dir_path}benign/benign (10).png', 'benign')
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
predict_image(f'{dir_path}benign/benign (85).png', 'benign')
# Out:
# 1/1 [==============================] - 0s 32ms/step

# %%
predict_image(f'{dir_path}malignant/malignant (10).png', 'malignant')
# Out:
# 1/1 [==============================] - 0s 31ms/step
